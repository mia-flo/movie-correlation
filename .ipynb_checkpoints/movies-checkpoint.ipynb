# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')

import re
from re import search

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Import the dataset

# %%
#data - 7668 intial entries

full_df = pd.read_csv(r'C:\Users\mflor\Desktop\data analysis projects\movies\movies.csv')
full_df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
#                               released  score      votes         director  \
# 0        June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1         July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2        June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3         July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4        July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
# ...                                ...    ...        ...              ...
# 7663  October 23, 2020 (United States)    3.1       18.0    Joseph Ebanks
# 7664  February 7, 2020 (United States)    4.7       36.0     Dusty Dukatz
# 7665         April 27, 2020 (Cameroon)    5.7       29.0     Nkanya Nkwai
# 7666   October 1, 2020 (United States)    NaN        NaN    James Randall
# 7667   August 19, 2020 (United States)    5.7        7.0     Pereko Mosia
#
#                        writer              star         country      budget  \
# 0                Stephen King    Jack Nicholson  United Kingdom  19000000.0
# 1     Henry De Vere Stacpoole    Brooke Shields   United States   4500000.0
# 2              Leigh Brackett       Mark Hamill   United States  18000000.0
# 3                Jim Abrahams       Robert Hays   United States   3500000.0
# 4          Brian Doyle-Murray       Chevy Chase   United States   6000000.0
# ...                       ...               ...             ...         ...
# 7663            Joseph Ebanks      Shannon Bond   United States      7000.0
# 7664              Lisa Huston  Michael Saquella   United States         NaN
# 7665             Lynno Lovert      Onyama Laura   United States     58750.0
# 7666            James Randall     Christina Roz   United States     15000.0
# 7667             Pereko Mosia  Siyabonga Mabaso    South Africa         NaN
#
#             gross                    company  runtime
# 0      46998772.0               Warner Bros.    146.0
# 1      58853106.0          Columbia Pictures    104.0
# 2     538375067.0                  Lucasfilm    124.0
# 3      83453539.0         Paramount Pictures     88.0
# 4      39846344.0             Orion Pictures     98.0
# ...           ...                        ...      ...
# 7663          NaN                        NaN     90.0
# 7664          NaN  Cactus Blue Entertainment     90.0
# 7665          NaN           Embi Productions      NaN
# 7666          NaN                        NaN    120.0
# 7667          NaN                PK 65 Films    102.0
#
# [7668 rows x 15 columns]

# %% [markdown]
# ## Data

# %%
full_df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
#how much data is missing per column (null values)
for col in full_df.columns:
    percent_missing = 100*np.mean(full_df[col].isnull())
    print('{}-{}%'.format(col, percent_missing))
# Out:
# name-0.0%
# rating-1.004173187271779%
# genre-0.0%
# year-0.0%
# released-0.02608242044861763%
# score-0.03912363067292645%
# votes-0.03912363067292645%
# director-0.0%
# writer-0.03912363067292645%
# star-0.013041210224308816%
# country-0.03912363067292645%
# budget-28.31246739697444%
# gross-2.464788732394366%
# company-0.2217005738132499%
# runtime-0.05216484089723526%

# %%
#no duplicates found based on movie title
full_df['name'].drop_duplicates()
full_df.shape
# Out:
# (7668, 15)

# %%
#delete entries that contain NaN in any field and then update the indexes for the dataframe
    #5421 entries left
df = full_df.dropna(inplace=False)
df.reset_index(inplace=True)

# %%
#changing data types

convert_dict = {
    'rating': 'category',
    'genre': 'category',
    'votes': 'int64',
    'budget': 'int64',
    'gross': 'int64',
    'runtime': 'int64'
}

df.astype(convert_dict)
df.dtypes
# Out:
# index         int64
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
#the country column sometimes does not match the country included in the release date column
df[['name','country','released']].head(50)
# Out:
#                                               name         country  \
# 0                                      The Shining  United Kingdom
# 1                                  The Blue Lagoon   United States
# 2   Star Wars: Episode V - The Empire Strikes Back   United States
# 3                                        Airplane!   United States
# 4                                       Caddyshack   United States
# 5                                  Friday the 13th   United States
# 6                               The Blues Brothers   United States
# 7                                      Raging Bull   United States
# 8                                      Superman II   United States
# 9                                  The Long Riders   United States
# 10                           Any Which Way You Can   United States
# 11                          The Gods Must Be Crazy    South Africa
# 12                                          Popeye   United States
# 13                                 Ordinary People   United States
# 14                                 Dressed to Kill   United States
# 15                               Somewhere in Time   United States
# 16                                          9 to 5   United States
# 17                                         The Fog   United States
# 18                                        Cruising    West Germany
# 19                                   Heaven's Gate   United States
# 20                             The Final Countdown   United States
# 21                                          Xanadu   United States
# 22                                        Brubaker   United States
# 23                                 American Gigolo   United States
# 24                Cattle Annie and Little Britches   United States
# 25                                Private Benjamin   United States
# 26                           The Hollywood Knights   United States
# 27                                      Motel Hell   United States
# 28                                   The Stunt Man   United States
# 29                                      The Island   United States
# 30                                   The Nude Bomb   United States
# 31                               Stardust Memories   United States
# 32                               Melvin and Howard   United States
# 33                                    Bronco Billy   United States
# 34                            When Time Ran Out...   United States
# 35                                 Oh Heavenly Dog   United States
# 36                                     The Octagon   United States
# 37                   The Last Flight of Noah's Ark   United States
# 38                                   Willie & Phil   United States
# 39                                          Phobia          Canada
# 40   Indiana Jones and the Raiders of the Lost Ark   United States
# 41                  An American Werewolf in London  United Kingdom
# 42                            Escape from New York   United States
# 43                                   The Evil Dead   United States
# 44                                         Porky's          Canada
# 45                                        Blow Out   United States
# 46                             Clash of the Titans  United Kingdom
# 47                                       Excalibur  United Kingdom
# 48                                       Mad Max 2       Australia
# 49                                         Stripes   United States
#
#                               released
# 0        June 13, 1980 (United States)
# 1         July 2, 1980 (United States)
# 2        June 20, 1980 (United States)
# 3         July 2, 1980 (United States)
# 4        July 25, 1980 (United States)
# 5          May 9, 1980 (United States)
# 6        June 20, 1980 (United States)
# 7    December 19, 1980 (United States)
# 8        June 19, 1981 (United States)
# 9         May 16, 1980 (United States)
# 10   December 17, 1980 (United States)
# 11    October 26, 1984 (United States)
# 12   December 12, 1980 (United States)
# 13  September 19, 1980 (United States)
# 14       July 25, 1980 (United States)
# 15     October 3, 1980 (United States)
# 16   December 19, 1980 (United States)
# 17    February 8, 1980 (United States)
# 18   February 15, 1980 (United States)
# 19      April 24, 1981 (United States)
# 20      August 1, 1980 (United States)
# 21      August 8, 1980 (United States)
# 22       June 20, 1980 (United States)
# 23    February 1, 1980 (United States)
# 24      April 24, 1981 (United States)
# 25    October 10, 1980 (United States)
# 26        May 30, 1980 (United States)
# 27    October 24, 1980 (United States)
# 28       June 27, 1980 (United States)
# 29       June 13, 1980 (United States)
# 30         May 9, 1980 (United States)
# 31  September 26, 1980 (United States)
# 32  September 19, 1980 (United States)
# 33       June 11, 1980 (United States)
# 34      March 28, 1980 (United States)
# 35       July 11, 1980 (United States)
# 36     August 15, 1980 (United States)
# 37       June 25, 1980 (United States)
# 38     August 15, 1980 (United States)
# 39   September 9, 1980 (United States)
# 40       June 12, 1981 (United States)
# 41     August 21, 1981 (United States)
# 42       July 10, 1981 (United States)
# 43      April 15, 1983 (United States)
# 44      March 19, 1982 (United States)
# 45       July 24, 1981 (United States)
# 46       June 12, 1981 (United States)
# 47      April 10, 1981 (United States)
# 48        May 21, 1982 (United States)
# 49       June 26, 1981 (United States)

# %%
#some values for the year column do not match the year from the released col
df[['name','year','released']].tail(50)
# Out:
#                                    name  year  \
# 5371                      What Men Want  2019
# 5372                       Pet Sematary  2019
# 5373            47 Meters Down: Uncaged  2019
# 5374                 Happy Death Day 2U  2019
# 5375                Weathering with You  2019
# 5376                            The Kid  2019
# 5377  The Lego Movie 2: The Second Part  2019
# 5378                       Child's Play  2019
# 5379                              Dumbo  2019
# 5380                         The Hustle  2019
# 5381                              Shaft  2019
# 5382                      The Beach Bum  2019
# 5383                        The Kitchen  2019
# 5384                             Stuber  2019
# 5385      The Art of Racing in the Rain  2019
# 5386               Blinded by the Light  2019
# 5387         Where'd You Go, Bernadette  2019
# 5388               Ip Man 4: The Finale  2019
# 5389                         Abominable  2019
# 5390                  Isn't It Romantic  2019
# 5391                    A Dog's Journey  2019
# 5392                       Don't Let Go  2019
# 5393                          UglyDolls  2019
# 5394                            Tolkien  2019
# 5395                          Miss Bala  2019
# 5396                   A Dog's Way Home  2019
# 5397                        Wonder Park  2019
# 5398                      Triple Threat  2019
# 5399                The Wandering Earth  2019
# 5400          The Kid Who Would Be King  2019
# 5401                       Missing Link  2019
# 5402                       Breakthrough  2019
# 5403                               Poms  2019
# 5404                             Little  2019
# 5405                        The Prodigy  2019
# 5406                          Overcomer  2019
# 5407             A Madea Family Funeral  2019
# 5408             The Sun Is also a Star  2019
# 5409                               K-12  2019
# 5410                          Unplanned  2019
# 5411                             Mine 9  2019
# 5412                    High on the Hog  2019
# 5413                              Tenet  2020
# 5414                      Birds of Prey  2020
# 5415                  The Invisible Man  2020
# 5416                  Bad Boys for Life  2020
# 5417                 Sonic the Hedgehog  2020
# 5418                           Dolittle  2020
# 5419               The Call of the Wild  2020
# 5420                  The Eight Hundred  2020
#
#                                 released
# 5371    February 8, 2019 (United States)
# 5372       April 5, 2019 (United States)
# 5373     August 16, 2019 (United States)
# 5374   February 13, 2019 (United States)
# 5375    January 17, 2020 (United States)
# 5376       March 8, 2019 (United States)
# 5377    February 8, 2019 (United States)
# 5378       June 21, 2019 (United States)
# 5379      March 29, 2019 (United States)
# 5380        May 10, 2019 (United States)
# 5381       June 14, 2019 (United States)
# 5382      March 29, 2019 (United States)
# 5383      August 9, 2019 (United States)
# 5384       July 12, 2019 (United States)
# 5385      August 9, 2019 (United States)
# 5386     August 16, 2019 (United States)
# 5387     August 16, 2019 (United States)
# 5388           December 20, 2019 (China)
# 5389  September 27, 2019 (United States)
# 5390   February 13, 2019 (United States)
# 5391        May 17, 2019 (United States)
# 5392     August 30, 2019 (United States)
# 5393         May 3, 2019 (United States)
# 5394        May 10, 2019 (United States)
# 5395    February 1, 2019 (United States)
# 5396    January 11, 2019 (United States)
# 5397      March 15, 2019 (United States)
# 5398              March 29, 2019 (China)
# 5399            February 5, 2019 (China)
# 5400    January 25, 2019 (United States)
# 5401      April 12, 2019 (United States)
# 5402      April 17, 2019 (United States)
# 5403        May 10, 2019 (United States)
# 5404      April 12, 2019 (United States)
# 5405    February 8, 2019 (United States)
# 5406     August 23, 2019 (United States)
# 5407       March 1, 2019 (United States)
# 5408        May 17, 2019 (United States)
# 5409   September 5, 2019 (United States)
# 5410      March 29, 2019 (United States)
# 5411               May 19, 2020 (Poland)
# 5412      April 16, 2019 (United States)
# 5413   September 3, 2020 (United States)
# 5414    February 7, 2020 (United States)
# 5415   February 28, 2020 (United States)
# 5416    January 17, 2020 (United States)
# 5417   February 14, 2020 (United States)
# 5418    January 17, 2020 (United States)
# 5419   February 21, 2020 (United States)
# 5420     August 28, 2020 (United States)

# %% [markdown]
# ## Summary statistics

# %%
#summary of categorical features
df.describe(include='object')
# Out:
#             name rating   genre                         released     director  \
# count       5421   5421    5421                             5421         5421
# unique      5336     10      15                             2560         2063
# top     Hercules      R  Comedy  August 26, 2016 (United States)  Woody Allen
# freq           3   2597    1496                                7           33
#
#              writer          star        country             company
# count          5421          5421           5421                5421
# unique         3205          1845             50                1475
# top     Woody Allen  Nicolas Cage  United States  Universal Pictures
# freq             32            40           4319                 330

# %%
#numerical features
df.describe(include=['int64','float64'])
# Out:
#              index         year        score         votes        budget  \
# count  5421.000000  5421.000000  5421.000000  5.421000e+03  5.421000e+03
# mean   4069.060505  2001.661317     6.392455  1.150661e+05  3.600917e+07
# std    2097.297246    10.540908     0.962730  1.844073e+05  4.157337e+07
# min       0.000000  1980.000000     1.900000  1.950000e+02  6.000000e+03
# 25%    2389.000000  1993.000000     5.800000  1.900000e+04  1.000000e+07
# 50%    4187.000000  2002.000000     6.500000  5.200000e+04  2.180000e+07
# 75%    5844.000000  2011.000000     7.100000  1.290000e+05  4.500000e+07
# max    7652.000000  2020.000000     9.300000  2.400000e+06  3.560000e+08
#
#               gross      runtime
# count  5.421000e+03  5421.000000
# mean   1.032297e+08   108.152739
# std    1.873027e+08    18.115698
# min    3.090000e+02    63.000000
# 25%    1.073640e+07    95.000000
# 50%    3.686941e+07   105.000000
# 75%    1.124625e+08   118.000000
# max    2.847246e+09   271.000000

# %%
#distribution of numerical features
df.hist()
# Out:
# array([[<Axes: title={'center': 'year'}>,
#         <Axes: title={'center': 'score'}>],
#        [<Axes: title={'center': 'votes'}>,
#         <Axes: title={'center': 'budget'}>],
#        [<Axes: title={'center': 'gross'}>,
#         <Axes: title={'center': 'runtime'}>]], dtype=object)

# %% [markdown]
# budget, votes, gross, runtime are skewed right
#
# year has a very broad, slightly left skewed distribution

# %%
#outliers?
sns.boxplot(x=df['budget'])
plt.title('Budget Distribution in the Billions')
# Out:
# Text(0.5, 1.0, 'Budget Distribution in the Billions')

# %% [markdown]
# positively skewed

# %%
sns.boxplot(x=df['gross'])
plt.title('Gross Distribution in the Billions')
# Out:
# Text(0.5, 1.0, 'Gross Distribution in the Billions')

# %% [markdown]
# positively skewed

# %% [markdown]
# ## Correlations

# %%
#heatmap of all correlations between numerical features - what are some notable relationships within the dataset?
corr_mat = df.corr(numeric_only=True)
sns.heatmap(corr_mat, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# The matrix shows mostly no relation-to weak relationships.
#
# __weak: 0.1-0.3  moderate: 0.4-0.6  strong: 0.7-0.9__

# %%
#unstacking the correlation matrix to find the strongest relationships
corr_pairs = corr_mat.unstack()
sorted_pairs = corr_pairs.sort_values(kind='quicksort')

# %%
#sorting the relationships
pairs = sorted_pairs[abs(sorted_pairs) < 1.00]
strong_pairs = pairs[abs(pairs) > 0.7]

moderate_pairs = pairs[abs(pairs) > 0.4]
moderate_pairs = moderate_pairs[abs(moderate_pairs) < 0.6]

weak_pairs = pairs[abs(pairs) > 0.1]
weak_pairs = weak_pairs[abs(weak_pairs) < 0.3]

print(f'''Strong relationships:\n{strong_pairs} 
        Moderate relationships: \n{moderate_pairs} 
        Weak relationships: \n{weak_pairs}''')
# Out:
# Strong relationships:
# gross   budget    0.740247
# budget  gross     0.740247
# year    index     0.999522
# index   year      0.999522
# dtype: float64
#         Moderate relationships:
# score    runtime    0.414068
# runtime  score      0.414068
# votes    budget     0.439675
# budget   votes      0.439675
# score    votes      0.474256
# votes    score      0.474256
# dtype: float64
#         Weak relationships:
# votes    index      0.192525
# index    votes      0.192525
# votes    year       0.206021
# year     votes      0.206021
# gross    score      0.222556
# score    gross      0.222556
# index    gross      0.264121
# gross    index      0.264121
#          year       0.274321
# year     gross      0.274321
# gross    runtime    0.275796
# runtime  gross      0.275796
# dtype: float64

# %% [markdown]
# ## Linear regression

# %%
#budget vs gross
sns.set_context('paper', font_scale=1.4)
sns.lmplot(x='budget', y='gross', data=df, x_jitter=0.05, 
           scatter_kws={'s': 50, 'linewidth': 0.5, 'edgecolor': 'w', 'color': 'red'},
          line_kws={'color': 'blue'})
corr = df['budget'].corr(df['gross'])
plt.title('Budget vs Gross')
print(corr)
# Out:
# 0.740246543921963

# %%
sns.set_context('paper', font_scale=1.4)
sns.lmplot(x='budget', y='votes', data=df, x_jitter = 0.05, 
           scatter_kws={'s': 50, 'linewidth': 0.5, 'edgecolor': 'w', 
            'color': 'red'}, line_kws={'color': 'blue'})
corr = df['budget'].corr(df['votes'])
plt.title('Budget vs Audience Votes')
print(corr)
# Out:
# 0.43967507624301827

# %%
#scores vs votes
sns.set_context('paper', font_scale=1.4)
sns.lmplot(x='score', y='votes', data=df, scatter_kws={'s': 50, 'linewidth': 0.5, 'edgecolor': 'w',
         'color': 'red'}, line_kws={'color': 'blue'})
corr = df['score'].corr(df['votes'])
plt.title('Audience Score vs Votes')
print(corr)
# Out:
# 0.4742562481509454

# %%
#scores vs votes
sns.set_context('paper', font_scale=1.4)
sns.lmplot(x='score', y='runtime', data=df, scatter_kws={'s': 50, 'linewidth': 0.5, 'edgecolor': 'w', 
        'color': 'red'}, line_kws={'color': 'blue'})
corr = df['score'].corr(df['runtime'])
plt.title('Score vs Runtime')
print(corr)
# Out:
# 0.41406772196348474

# %% [markdown]
# ## What companies bring in the most revenue?

# %%
#top 15 companies by gross

company_gross = df.groupby('company')[['gross']].sum()

company_gross_sorted = company_gross.sort_values('gross', ascending=False)[:20]

company_gross_sorted
# Out:
#                                       gross
# company
# Warner Bros.                   5.461096e+10
# Universal Pictures             5.124111e+10
# Columbia Pictures              4.235643e+10
# Paramount Pictures             4.002170e+10
# Twentieth Century Fox          3.954257e+10
# Walt Disney Pictures           3.583365e+10
# New Line Cinema                1.961285e+10
# Marvel Studios                 1.506559e+10
# DreamWorks Animation           1.187361e+10
# Dreamworks Pictures            1.159381e+10
# Touchstone Pictures            1.066468e+10
# Metro-Goldwyn-Mayer (MGM)      8.937010e+09
# Summit Entertainment           8.318570e+09
# Pixar Animation Studios        7.886345e+09
# Fox 2000 Pictures              7.243674e+09
# Lucasfilm                      7.185352e+09
# Walt Disney Animation Studios  6.751509e+09
# Lionsgate                      6.050518e+09
# TriStar Pictures               5.405033e+09
# Screen Gems                    4.113025e+09

# %% [markdown]
# ## Which companies have released the most films?

# %%
#top 20 companies by number of films released
df['company'].value_counts()[:20]
# Out:
# Universal Pictures           330
# Columbia Pictures            302
# Warner Bros.                 298
# Paramount Pictures           279
# Twentieth Century Fox        209
# New Line Cinema              155
# Walt Disney Pictures         107
# Touchstone Pictures          105
# Metro-Goldwyn-Mayer (MGM)     99
# Dreamworks Pictures           75
# TriStar Pictures              75
# Miramax                       66
# Fox 2000 Pictures             58
# Summit Entertainment          57
# Screen Gems                   56
# Lionsgate                     53
# Dimension Films               50
# Fox Searchlight Pictures      48
# Orion Pictures                47
# Castle Rock Entertainment     45
# Name: company, dtype: int64

# %% [markdown]
# ## How have movie budgets and gross changed over the years?

# %%
#summing gross by year
gross_over_yrs = df.groupby('year')[['gross']].sum()
gross_yr_sorted = gross_over_yrs.sort_values('year', ascending=False)

#summing budget by year
budget_over_yrs = df.groupby('year')[['budget']].sum()
budget_yr_sorted = budget_over_yrs.sort_values('year', ascending=False)


sns.set_context(context='paper')
g = sns.lineplot(gross_yr_sorted, palette=['g'])
b = sns.lineplot(budget_yr_sorted, palette=['b'])

#title and legend
plt.title('Change in Film Budgets and Gross over time')
g.legend(fontsize=15)
b.legend(fontsize=15)
g.title.set_size(20)

# %% [markdown]
# ## Distribution of movie genres

# %%
sns.set_context(context='paper')
axes = sns.stripplot(x='rating', y='gross', data=df, hue='rating', jitter=0.25, linewidth=0.5, edgecolor='white')
plt.title('Film Rating vs Gross')
axes.title.set_size(20)

# %%
sns.set_context(context='paper')
axes = sns.stripplot(x='genre', y='gross', data=df, hue='genre', jitter=0.25, linewidth=0.5, edgecolor='white')
plt.title('Film Genre vs Gross')
axes.title.set_size(20)
